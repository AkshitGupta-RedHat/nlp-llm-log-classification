# %%
from webbrowser import open_new

import pandas as pd
from sklearn.linear_model import LogisticRegression
from transformers.agents.default_tools import custom_print

df = pd.read_csv("dataset/synthetic_logs.csv")
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
#
#   complexity
# 0       bert
# 1       bert
# 2       bert
# 3       bert
# 4       bert

# %%
df.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI', 'LegacyCRM'], dtype=object)

# %%
df.target_label.unique()
# Out:
# array(['HTTP Status', 'Critical Error', 'Security Alert', 'Error',
#        'System Notification', 'Resource Usage', 'User Action',
#        'Workflow Error', 'Deprecation Warning'], dtype=object)

# %%
from sklearn.cluster import DBSCAN
from sentence_transformers import SentenceTransformer
import numpy as np

# Load pre-trained SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for log messages
embeddings = model.encode(df['log_message'].values, convert_to_tensor=True)

embeddings[:2]
# Out:
# tensor([[-1.0294e-01,  3.3546e-02, -2.2026e-02,  1.5510e-03, -9.8692e-03,
#          -1.7896e-01, -6.3441e-02, -6.0176e-02,  2.8111e-02,  5.9962e-02,
#          -1.7262e-02,  1.4336e-03, -1.4956e-01,  3.1529e-03, -5.6603e-02,
#           2.7169e-02, -1.4989e-02, -3.5404e-02, -3.6294e-02, -1.4541e-02,
#          -5.6149e-03,  8.7554e-02,  4.5512e-02,  2.5096e-02,  1.0019e-02,
#           1.2427e-02, -1.3992e-01,  7.6870e-02,  3.1410e-02, -4.1525e-03,
#           4.3690e-02,  1.7125e-02, -8.0095e-02,  5.7401e-02,  1.8909e-02,
#           8.5526e-02,  3.9640e-02, -1.3437e-01, -1.4436e-03,  3.0670e-03,
#           1.7685e-01,  4.4489e-03, -1.6927e-02,  2.2427e-02, -4.3505e-02,
#           6.0903e-03, -9.9817e-03, -6.2397e-02,  1.0737e-02, -6.0490e-03,
#          -7.1466e-02, -8.4580e-03, -3.1802e-02, -1.0052e-01,  2.2587e-04,
#          -1.8934e-02, -3.1779e-02,  4.0086e-02,  2.1918e-02, -2.5953e-02,
#           5.8453e-02, -8.1251e-02,  2.1203e-02, -5.0269e-02,  1.3206e-02,
#           1.3268e-03,  2.2706e-02, -3.4579e-02,  3.9155e-02, -2.0943e-02,
#           3.2483e-03,  4.4396e-02, -9.8536e-02, -2.8890e-02, -6.8502e-03,
#           5.3882e-02,  6.4611e-02, -2.4506e-02,  9.2183e-02, -7.4987e-02,
#           1.2399e-02, -1.0003e-01, -4.6491e-02,  6.0157e-02, -2.4648e-02,
#          -7.0808e-02, -2.7727e-02,  9.7261e-02,  3.8584e-02, -1.4429e-02,
#          -7.4691e-04, -1.0430e-02, -1.6184e-02,  4.4363e-02,  9.2600e-03,
#           7.1417e-02,  6.3792e-02,  4.9493e-02, -6.0257e-02,  4.0481e-02,
#          -3.4286e-02, -1.9388e-02,  6.6123e-02,  6.0159e-02,  1.0937e-02,
#          -5.3863e-03,  1.4458e-02,  9.2543e-02, -3.1456e-02, -1.8435e-02,
#           9.9188e-03, -1.8557e-02,  1.3128e-03,  2.2670e-05,  2.0274e-03,
#           2.7526e-02, -4.8193e-02,  5.4283e-02, -7.3207e-02,  4.8867e-02,
#           4.9849e-02, -9.0114e-03, -4.6891e-02, -4.2589e-02, -8.1952e-02,
#           3.8711e-02,  7.8550e-02,  1.4608e-32,  1.6671e-02,  5.2549e-02,
#          -1.8245e-02, -1.2669e-02,  6.5284e-02, -2.1178e-02, -4.0632e-02,
#           4.1495e-02, -2.4836e-02, -1.3307e-02, -5.4675e-02, -5.9920e-04,
#          -4.8925e-03, -6.2736e-02, -3.8488e-02, -6.1354e-02,  8.2741e-02,
#           3.0442e-02,  5.0988e-02,  6.7014e-02,  1.0404e-02,  1.6353e-02,
#           3.9203e-02,  2.1715e-02,  5.3660e-02,  3.6281e-02, -4.2214e-02,
#          -2.4723e-02,  1.9031e-02,  3.6172e-02,  6.3702e-02, -3.2158e-03,
#          -8.5039e-03,  3.9466e-02,  9.0266e-03,  1.9310e-02,  6.6072e-02,
#           1.0270e-02, -4.4385e-02, -1.5652e-02, -1.5571e-02,  1.3290e-02,
#          -1.1611e-02,  4.2183e-02, -5.4478e-02,  1.2924e-01, -2.2576e-02,
#           5.2620e-02, -1.5844e-02,  9.3317e-02,  6.3803e-03, -9.3616e-03,
#          -6.0888e-02, -3.2731e-02, -3.4482e-02,  3.2997e-02, -4.7939e-02,
#          -9.8130e-02,  2.9116e-02, -2.7090e-02,  1.8187e-02, -1.7386e-02,
#          -4.4037e-02, -7.9700e-02,  3.0165e-02, -6.3526e-02,  1.2596e-02,
#           8.5025e-02, -4.5891e-02,  5.8102e-02, -2.7100e-02,  8.4278e-02,
#          -4.0997e-02, -3.3766e-02,  1.0209e-02, -2.5419e-02, -1.4061e-08,
#           4.9445e-02, -9.0436e-02, -6.0671e-02,  8.2953e-02, -3.2903e-02,
#           4.1491e-02,  9.9959e-03,  6.9614e-03,  3.9923e-03, -3.2433e-02,
#          -3.1466e-02, -5.3316e-02, -3.8091e-02,  1.6208e-02,  2.4578e-02,
#          -7.2642e-02, -6.5689e-02, -8.2313e-02, -8.0050e-02, -5.3665e-02,
#           5.6089e-02, -1.1091e-02,  9.6220e-04, -1.2269e-01, -5.1384e-02,
#           9.9670e-03,  1.0070e-02,  1.0707e-01,  1.1976e-02,  1.0042e-02,
#          -6.2826e-02, -7.4970e-02, -6.3408e-03, -2.7220e-02, -1.2810e-01,
#          -2.6246e-02, -1.8146e-02, -9.8536e-02, -3.0299e-02, -4.0261e-02,
#           9.9429e-02,  5.3600e-02,  2.7490e-02, -5.5368e-03,  8.4357e-02,
#           8.3516e-02,  3.7431e-02,  7.1194e-02,  2.9890e-02,  2.3273e-02,
#          -3.6211e-02,  6.2054e-02,  2.1515e-02,  5.1973e-02,  1.4534e-02,
#          -4.6097e-02,  5.0255e-02, -7.2703e-02,  2.9278e-02,  5.6266e-02,
#          -3.8635e-02,  1.5383e-02, -6.2309e-02, -2.7747e-02]])

# %%
# Apply DBSCAN for clustering
dbscan = DBSCAN(eps=0.2, min_samples=1, metric='cosine')
clusters = dbscan.fit_predict(embeddings)

# Add cluster labels to the DataFrame
df['cluster_label'] = clusters

df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                                                                                                                                                                                                                                                         log_message  \
# 0             nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118
# 1                                                                                                                                                                                                                                    Email service experiencing issues with sending
# 2                                                                                                                                                                                                                                         Unauthorized access to data was attempted
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b2f8-488f-a2a3-4fae63982e48 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" HTTP status code -  200 len: 211 time: 0.0968180
# 4              nova.osapi_compute.wsgi.server [req-ee8bc8ba-9265-4280-9215-dbe000a41209 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.2280791
#
#      target_label complexity  cluster_label
# 0     HTTP Status       bert              0
# 1  Critical Error       bert              1
# 2  Security Alert       bert              2
# 3     HTTP Status       bert              0
# 4     HTTP Status       bert              0

# %%
df[df['cluster_label'] == 1]
# Out:
#              timestamp           source  \
# 1      1/14/2025 23:07        ModernCRM
# 10      8/9/2025 18:58        ModernCRM
# 217     1/22/2025 5:45    BillingSystem
# 248     5/2/2025 23:04         ModernHR
# 265    3/30/2025 23:53        ModernCRM
# 361   11/19/2025 23:06    BillingSystem
# 450    10/27/2025 5:59    ThirdPartyAPI
# 477    12/2/2025 10:30  AnalyticsEngine
# 570    11/7/2025 18:08    ThirdPartyAPI
# 678    4/28/2025 15:13  AnalyticsEngine
# 695    6/30/2025 12:46    ThirdPartyAPI
# 816      7/9/2025 9:38    BillingSystem
# 926     2/17/2025 8:01        ModernCRM
# 1011    2/9/2025 17:04  AnalyticsEngine
# 1018   2/16/2025 15:02    BillingSystem
# 1046  11/26/2025 22:54  AnalyticsEngine
# 1058   10/24/2025 5:37  AnalyticsEngine
# 1082   5/17/2025 11:20         ModernHR
# 1151   6/17/2025 15:13    ThirdPartyAPI
# 1176   10/1/2025 12:27  AnalyticsEngine
# 1189     2/9/2025 6:15        ModernCRM
# 1359   8/18/2025 15:58        ModernCRM
# 1414   6/22/2025 23:07        ModernCRM
# 1427  10/26/2025 20:25         ModernHR
# 1453    9/11/2025 1:18    BillingSystem
# 1554     3/2/2025 9:21        ModernCRM
# 1567   5/11/2025 11:17    ThirdPartyAPI
# 1582    9/10/2025 9:27    BillingSystem
# 1860    6/26/2025 1:08    BillingSystem
# 1867   10/6/2025 11:04        ModernCRM
# 1901    9/22/2025 2:52    ThirdPartyAPI
# 1972    3/12/2025 3:48    ThirdPartyAPI
# 2049   10/1/2025 22:07  AnalyticsEngine
# 2165    4/4/2025 16:11    ThirdPartyAPI
# 2281   3/23/2025 20:12    ThirdPartyAPI
# 2284   10/4/2025 18:15    BillingSystem
# 2312    3/9/2025 21:16         ModernHR
# 2340    3/26/2025 8:10        ModernCRM
# 2408  11/11/2025 11:52    BillingSystem
#
#                                              log_message    target_label  \
# 1         Email service experiencing issues with sending  Critical Error
# 10              Email server encountered a sending fault           Error
# 217           Mail service encountered a delivery glitch           Error
# 248     Service disruption caused by email sending error  Critical Error
# 265            Email system had a problem sending emails           Error
# 361            Email service experienced a sending issue           Error
# 450           Email delivery system encountered an error           Error
# 477       Email transmission error caused service impact  Critical Error
# 570            Email service impacted by sending failure  Critical Error
# 678               Email delivery problem affected system  Critical Error
# 695         Service outage due to email delivery problem  Critical Error
# 816             Error in email delivery affected service  Critical Error
# 926            Email service suffered a delivery failure           Error
# 1011             Error in email sending impacted service  Critical Error
# 1018            Mail service impacted by delivery glitch  Critical Error
# 1046  Email service had a difficulty delivering messages           Error
# 1058               Email system failed to deliver emails           Error
# 1082            Delivery failure impacted email services  Critical Error
# 1151              Mail service was unable to send emails           Error
# 1176           Email provider faced a delivery challenge           Error
# 1189        Service issue caused by email delivery error  Critical Error
# 1359              Email system down due to sending error  Critical Error
# 1414            Email system encountered a sending error           Error
# 1427           Email provider had trouble sending emails           Error
# 1453          Mail delivery error impacted email service  Critical Error
# 1554      Email system had a difficulty sending messages           Error
# 1567           Email system affected by delivery failure  Critical Error
# 1582    Email delivery failure resulted in service issue  Critical Error
# 1860    Email provider experienced a mail delivery issue           Error
# 1867             Email service had a sending malfunction           Error
# 1901      Email service experienced a mail sending issue           Error
# 1972     Delivery issue with email service caused outage  Critical Error
# 2049         Email server experienced a delivery problem           Error
# 2165        Email server had trouble transmitting emails           Error
# 2281       Mail delivery issue caused service disruption  Critical Error
# 2284        Email service down due to transmission issue  Critical Error
# 2312             Email service faced a delivery obstacle           Error
# 2340      Service outage due to email transmission error  Critical Error
# 2408       Email service affected by failed transmission  Critical Error
#
#      complexity  cluster_label
# 1          bert              1
# 10         bert              1
# 217        bert              1
# 248        bert              1
# 265        bert              1
# 361        bert              1
# 450        bert              1
# 477        bert              1
# 570        bert              1
# 678        bert              1
# 695        bert              1
# 816        bert              1
# 926        bert              1
# 1011       bert              1
# 1018       bert              1
# 1046       bert              1
# 1058       bert              1
# 1082       bert              1
# 1151       bert              1
# 1176       bert              1
# 1189       bert              1
# 1359       bert              1
# 1414       bert              1
# 1427       bert              1
# 1453       bert              1
# 1554       bert              1
# 1567       bert              1
# 1582       bert              1
# 1860       bert              1
# 1867       bert              1
# 1901       bert              1
# 1972       bert              1
# 2049       bert              1
# 2165       bert              1
# 2281       bert              1
# 2284       bert              1
# 2312       bert              1
# 2340       bert              1
# 2408       bert              1

# %%
small_clusters = cluster_counts[cluster_counts < 5].index
for cluster in small_clusters:
    print(f"Cluster {cluster}:")
    print(df[df['cluster_label'] == cluster]['target_label'].unique())
    print()
# Out:
# Cluster 76:
# ['Security Alert']
#
# Cluster 97:
# ['Security Alert']
#
# Cluster 2:
# ['Security Alert']
#
# Cluster 19:
# ['Security Alert']
#
# Cluster 15:
# ['Security Alert']
#
# Cluster 67:
# ['Critical Error']
#
# Cluster 69:
# ['Security Alert']
#
# Cluster 65:
# ['Critical Error']
#
# Cluster 64:
# ['Security Alert']
#
# Cluster 33:
# ['Security Alert']
#
# Cluster 39:
# ['Security Alert']
#
# Cluster 37:
# ['Error']
#
# Cluster 35:
# ['Security Alert']
#
# Cluster 54:
# ['Security Alert']
#
# Cluster 50:
# ['Error']
#
# Cluster 63:
# ['Security Alert']
#
# Cluster 60:
# ['Security Alert']
#
# Cluster 56:
# ['Error']
#
# Cluster 46:
# ['Error']
#
# Cluster 44:
# ['Security Alert']
#
# Cluster 41:
# ['Security Alert']
#
# Cluster 71:
# ['Error']
#
# Cluster 58:
# ['Error']
#
# Cluster 57:
# ['Error']
#
# Cluster 88:
# ['Error']
#
# Cluster 94:
# ['Security Alert']
#
# Cluster 101:
# ['Security Alert']
#
# Cluster 98:
# ['Security Alert']
#
# Cluster 89:
# ['Error']
#
# Cluster 72:
# ['Security Alert']
#
# Cluster 78:
# ['Error']
#
# Cluster 87:
# ['Security Alert']
#
# Cluster 84:
# ['Security Alert']
#
# Cluster 23:
# ['Error']
#
# Cluster 22:
# ['Error']
#
# Cluster 29:
# ['Security Alert']
#
# Cluster 27:
# ['Critical Error']
#
# Cluster 107:
# ['Security Alert']
#
# Cluster 117:
# ['Security Alert']
#
# Cluster 104:
# ['Critical Error']
#
# Cluster 75:
# ['Security Alert']
#
# Cluster 80:
# ['Error']
#
# Cluster 90:
# ['Security Alert']
#
# Cluster 116:
# ['Critical Error']
#
# Cluster 96:
# ['Security Alert']
#
# Cluster 120:
# ['Critical Error']
#
# Cluster 36:
# ['Critical Error']
#
# Cluster 47:
# ['Security Alert']
#
# Cluster 61:
# ['Security Alert']
#
# Cluster 30:
# ['Critical Error']
#
# Cluster 74:
# ['Security Alert']
#
# Cluster 79:
# ['Security Alert']
#
# Cluster 83:
# ['Critical Error']
#
# Cluster 123:
# ['Critical Error']
#
# Cluster 68:
# ['Security Alert']
#
# Cluster 48:
# ['Deprecation Warning']
#
# Cluster 43:
# ['Critical Error']
#
# Cluster 40:
# ['Critical Error']
#
# Cluster 49:
# ['Security Alert']
#
# Cluster 55:
# ['Security Alert']
#
# Cluster 24:
# ['Workflow Error']
#
# Cluster 28:
# ['Security Alert']
#
# Cluster 62:
# ['Workflow Error']
#
# Cluster 86:
# ['Security Alert']
#
# Cluster 95:
# ['Critical Error']
#
# Cluster 73:
# ['Security Alert']
#
# Cluster 85:
# ['Critical Error']
#
# Cluster 81:
# ['Critical Error']
#
# Cluster 77:
# ['Security Alert']
#
# Cluster 103:
# ['Security Alert']
#
# Cluster 102:
# ['Critical Error']
#
# Cluster 100:
# ['Error']
#
# Cluster 99:
# ['Security Alert']
#
# Cluster 92:
# ['Critical Error']
#
# Cluster 91:
# ['Critical Error']
#
# Cluster 108:
# ['Critical Error']
#
# Cluster 109:
# ['Security Alert']
#
# Cluster 111:
# ['Critical Error']
#
# Cluster 110:
# ['Security Alert']
#
# Cluster 112:
# ['Security Alert']
#
# Cluster 113:
# ['Security Alert']
#
# Cluster 115:
# ['Critical Error']
#
# Cluster 114:
# ['Security Alert']
#
# Cluster 105:
# ['Workflow Error']
#
# Cluster 106:
# ['Error']
#
# Cluster 119:
# ['Security Alert']
#
# Cluster 118:
# ['Deprecation Warning']
#
# Cluster 121:
# ['Security Alert']
#
# Cluster 122:
# ['Deprecation Warning']
#
# Cluster 124:
# ['Security Alert']
#
# Cluster 125:
# ['Critical Error']
#
# Cluster 126:
# ['Critical Error']
#
# Cluster 127:
# ['Security Alert']
#
# Cluster 128:
# ['Security Alert']
#
# Cluster 129:
# ['Security Alert']
#
# Cluster 130:
# ['Critical Error']
#
# Cluster 131:
# ['Critical Error']
#
# Cluster 132:
# ['Security Alert']
#
# Cluster 133:
# ['Workflow Error']
#
# Cluster 134:
# ['Critical Error']
#
# Cluster 135:
# ['Security Alert']

# %%
cluster_counts = df['cluster_label'].value_counts()
large_cluster = cluster_counts[cluster_counts > 10].index
for cluster in large_cluster:
    print(f"Cluster {cluster}:")
    print(df[df['cluster_label'] == cluster]['log_message'].head(5))
    print()
# Out:
# Cluster 0:
# 0               nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118
# 3    nova.osapi_compute.wsgi.server [req-4895c258-b2f8-488f-a2a3-4fae63982e48 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" HTTP status code -  200 len: 211 time: 0.0968180
# 4                nova.osapi_compute.wsgi.server [req-ee8bc8ba-9265-4280-9215-dbe000a41209 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.2280791
# 5          nova.osapi_compute.wsgi.server [req-f0bffbc3-5ab0-4916-91c1-0a61dd7d4ec2 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1874 time: 0.2131531
# 9                nova.osapi_compute.wsgi.server [req-2bf7cfee-a236-42f3-8fb1-96fefab0b302 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.1794369
# Name: log_message, dtype: object
#
# Cluster 5:
# 8               nova.compute.claims [req-a07ac654-8e81-416d-bfbb-189116b07969 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: bf8c824d-f099-4433-a41e-e3da7578262e] Total memory: 64172 MB, used: 512.00 MB
# 26         nova.compute.claims [req-d6986b54-3735-4a42-9074-0ba7d9717de9 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: af5f7392-f7d4-4298-b647-c98924c64aa1] memory limit: 96258.00 MB, free: 95746.00 MB
# 40    nova.compute.claims [req-72b4858f-049e-49e1-b31e-b562c5018eaf 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 63a0d960-70b6-44c6-b606-491478a5cadf] disk limit not specified, defaulting to unlimited
# 58    nova.compute.claims [req-5c8f52bd-8e3c-41f0-95a5-7861d247cafa 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: d96a117b-0193-4549-bdcc-63b917273d1d] vcpu limit not specified, defaulting to unlimited
# 61    nova.compute.claims [req-d38f479d-9bb9-4276-9688-52607e8fd350 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 95960536-049b-41f6-9049-05fc479b6a7c] disk limit not specified, defaulting to unlimited
# Name: log_message, dtype: object
#
# Cluster 11:
# 27     User User685 logged out.
# 57      User User395 logged in.
# 85      User User225 logged in.
# 88     User User494 logged out.
# 126     User User900 logged in.
# Name: log_message, dtype: object
#
# Cluster 13:
# 30     Backup started at 2025-05-14 07:06:55.
# 44     Backup started at 2025-02-15 20:00:19.
# 108      Backup ended at 2025-08-08 13:06:23.
# 128    Backup started at 2025-11-14 08:27:43.
# 191    Backup started at 2025-12-09 10:19:11.
# Name: log_message, dtype: object
#
# Cluster 7:
# 13     Multiple bad login attempts detected on user 8538 account
# 53         Multiple login failures occurred on user 9052 account
# 72              User 7153 made multiple incorrect login attempts
# 74              User 8300 made multiple incorrect login attempts
# 113          Multiple login failures were detected for user 6373
# Name: log_message, dtype: object
#
# Cluster 8:
# 15    Backup completed successfully.
# 52    Backup completed successfully.
# 54    Backup completed successfully.
# 81    Backup completed successfully.
# 83    Backup completed successfully.
# Name: log_message, dtype: object
#
# Cluster 21:
# 50     System updated to version 3.9.1.
# 176    System updated to version 5.5.4.
# 185    System updated to version 4.7.4.
# 192    System updated to version 3.7.7.
# 260    System updated to version 2.6.2.
# Name: log_message, dtype: object
#
# Cluster 3:
# 6                Shard 6 replication task ended in failure
# 45     Data replication task for shard 14 did not complete
# 98               Data replication task failed for shard 17
# 104                 Replication of data to shard 14 failed
# 190     Data replication task for shard 6 did not complete
# Name: log_message, dtype: object
#
# Cluster 4:
# 7      File data_6169.csv uploaded successfully by user User953.
# 14     File data_3847.csv uploaded successfully by user User175.
# 48     File data_7366.csv uploaded successfully by user User282.
# 129    File data_1206.csv uploaded successfully by user User359.
# 194    File data_1503.csv uploaded successfully by user User151.
# Name: log_message, dtype: object
#
# Cluster 17:
# 38         Denied access attempt on restricted account Account2682
# 67     Unauthorized login attempt on protected account Account5030
# 200                Account Account9437 blocked due to failed login
# 206         Account Account7999 access denied due to login failure
# 306      Invalid login attempt made on secured account Account7864
# Name: log_message, dtype: object
#
# Cluster 6:
# 11                             Critical system unit error: unit ID Component55
# 35                      System component malfunction: component ID Component79
# 115                    Critical system element is down: element ID Component96
# 175                      Essential system part malfunction: part ID Component6
# 204    Failure occurred in critical system component: component ID Component92
# Name: log_message, dtype: object
#
# Cluster 32:
# 96     Disk cleanup completed successfully.
# 160    Disk cleanup completed successfully.
# 208    Disk cleanup completed successfully.
# 225    Disk cleanup completed successfully.
# 252    Disk cleanup completed successfully.
# Name: log_message, dtype: object
#
# Cluster 16:
# 36     System reboot initiated by user User243.
# 92     System reboot initiated by user User471.
# 139    System reboot initiated by user User216.
# 140    System reboot initiated by user User639.
# 161    System reboot initiated by user User819.
# Name: log_message, dtype: object
#
# Cluster 20:
# 46                    User 7662 tried to bypass API security measures
# 159          User 2367 failed to provide valid API access credentials
# 229                        User 3569 made an unauthorized API request
# 279             Unauthorized user 2968 tried to access restricted API
# 368    User 2186 attempted to access API without proper authorization
# Name: log_message, dtype: object
#
# Cluster 9:
# 18     Account with ID 5351 created by User634.
# 122    Account with ID 7813 created by User373.
# 205    Account with ID 9827 created by User965.
# 259    Account with ID 2520 created by User546.
# 273    Account with ID 2300 created by User964.
# Name: log_message, dtype: object
#
# Cluster 1:
# 1        Email service experiencing issues with sending
# 10             Email server encountered a sending fault
# 217          Mail service encountered a delivery glitch
# 248    Service disruption caused by email sending error
# 265           Email system had a problem sending emails
# Name: log_message, dtype: object
#
# Cluster 10:
# 22       nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=512MB phys_disk=15GB used_disk=0GB total_vcpus=16 used_vcpus=0 pci_stats=[]
# 82     nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
# 120                                                                                                                              nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Total usable vcpus: 16, total allocated vcpus: 0
# 153    nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
# 238    nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
# Name: log_message, dtype: object
#
# Cluster 34:
# 100             Abnormal behavior found on server 10, possible security threat
# 169                            Security alert: suspicious activity on server 1
# 357    Anomalous activity identified on server 23, security review recommended
# 411         Server 27 experienced potential security incident, review required
# 467         Server 36 experienced potential security incident, review required
# Name: log_message, dtype: object
#
# Cluster 53:
# 283           Module X experienced an invalid data format issue
# 344                  Input format mismatch occurred in module X
# 378       Module X reported an error in input format validation
# 454    Module X failed to process input due to formatting error
# 530      Input data format in module X was invalid or corrupted
# Name: log_message, dtype: object
#
# Cluster 14:
# 32            Detection of multiple disk faults in RAID setup
# 69           RAID array suffered multiple hard drive failures
# 102              RAID array experienced multiple disk crashes
# 223    Multiple hard drive issues in RAID configuration found
# 300     Identification of multiple faulty disks in RAID array
# Name: log_message, dtype: object
#
# Cluster 52:
# 282         Service health check was not successful because of SSL certificate validation failures.
# 528                              Invalid SSL certificate resulted in a failed service health check.
# 545    Service health check failure was due to an invalid or improperly configured SSL certificate.
# 601                      An issue with the SSL certificate caused the service health check to fail.
# 734                          Service health check failure was caused by an expired SSL certificate.
# Name: log_message, dtype: object
#
# Cluster 18:
# 42         Boot process terminated unexpectedly due to kernel issue
# 416     System encountered kernel panic during initialization phase
# 827                  Boot process was stopped by kernel malfunction
# 956        System encountered kernel failure during bootup sequence
# 1073                       Boot sequence failed due to kernel panic
# Name: log_message, dtype: object
#
# Cluster 42:
# 195    User 5127 has escalated admin privileges without authorization
# 270                            User 9745 has escalated to admin level
# 299                     User 8483 escalated privileges to admin level
# 414                            User 1987 has escalated to admin level
# 604                     User 8395 escalated privileges to admin level
# Name: log_message, dtype: object
#
# Cluster 25:
# 62              System configuration is no longer valid
# 453    Configuration is corrupted throughout the system
# 578         Cross-system configuration failure occurred
# 731         System configuration is experiencing errors
# 917            Configuration malfunction is system-wide
# Name: log_message, dtype: object
#
# Cluster 59:
# 354     Potential security threat: Admin privilege escalation for user 5130
# 421                          Admin privilege escalation alert for user 2893
# 747                          Admin privilege escalation alert for user 8532
# 904     Potential security threat: Admin privilege escalation for user 1554
# 1334            Warning: Potential admin privilege escalation for user 5720
# Name: log_message, dtype: object
#
# Cluster 26:
# 76               Privilege elevation detected for user 5038
# 103    Elevation of admin privileges detected for user 6137
# 125    Elevation of admin privileges detected for user 4907
# 345    User 6069 has been granted elevated admin privileges
# 386         Admin privilege elevation warning for user 7574
# Name: log_message, dtype: object

# %%
import re
def classify_with_regex(log_message):
    regex_patterns = {
        r"User User\d+ logged (in|out)" : "User Action",
        r"Backup (started|ended) at .*" : "System Notification",
        r"Backup completed successfully" : "System Notification",
        r"System updated version .*" : "System Notification",
        r"File .* uploaded successfully" : "System Notification",
        r"Disk cleanup completed successfully" : "System Notification",
        r"System reboot initiated by user" : "System Notification",
        r"Account with ID .* created .*" : "User Action"
    }

    for pattern, label in regex_patterns.items():
        match = re.search(pattern, log_message, re.IGNORECASE)
        if match:
            return label
    return None

# %%
classify_with_regex("Account with ID fsdf created sdfsd")
# Out:
# 'User Action'

# %%
df["regex_classify"] = df["log_message"].apply(classify_with_regex)
df_non_regex = df[df["regex_classify"].isnull()]

df_non_regex
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                                                                                                                                                                                                                                                            log_message  \
# 0                nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118
# 1                                                                                                                                                                                                                                       Email service experiencing issues with sending
# 2                                                                                                                                                                                                                                            Unauthorized access to data was attempted
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b2f8-488f-a2a3-4fae63982e48 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" HTTP status code -  200 len: 211 time: 0.0968180
# 4                 nova.osapi_compute.wsgi.server [req-ee8bc8ba-9265-4280-9215-dbe000a41209 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.2280791
# ...                                                                                                                                                                                                                                                                                ...
# 2405        nova.osapi_compute.wsgi.server [req-96c3ec98-21a0-4af2-84a8-d4989512413e 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1916 time: 0.2677610
# 2406                                                                                                                                                                                                                              User 3844 account experienced multiple failed logins
# 2407                                                                                                   nova.metadata.wsgi.server [req-b6d4a270-accb-4c3a-8179-9611e52e1768 - - - - -] 10.11.21.124,10.11.10.1 "GET /openstack/2013-10-17 HTTP/1.1" RCODE  200 len: 157 time: 0.2249990
# 2408                                                                                                                                                                                                                                     Email service affected by failed transmission
# 2409                                                                                                                                                                                                                          Repeated failed login attempts occurred for user ID 8555
#
#         target_label complexity  cluster_label regex_classify
# 0        HTTP Status       bert              0           None
# 1     Critical Error       bert              1           None
# 2     Security Alert       bert              2           None
# 3        HTTP Status       bert              0           None
# 4        HTTP Status       bert              0           None
# ...              ...        ...            ...            ...
# 2405     HTTP Status       bert              0           None
# 2406  Security Alert       bert              7           None
# 2407     HTTP Status       bert              0           None
# 2408  Critical Error       bert              1           None
# 2409  Security Alert       bert              7           None
#
# [1968 rows x 7 columns]

# %%
df_not_regex = df[df["regex_classify"].isnull()]
df_not_regex
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                                                                                                                                                                                                                                                            log_message  \
# 0                nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118
# 1                                                                                                                                                                                                                                       Email service experiencing issues with sending
# 2                                                                                                                                                                                                                                            Unauthorized access to data was attempted
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b2f8-488f-a2a3-4fae63982e48 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" HTTP status code -  200 len: 211 time: 0.0968180
# 4                 nova.osapi_compute.wsgi.server [req-ee8bc8ba-9265-4280-9215-dbe000a41209 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.2280791
# ...                                                                                                                                                                                                                                                                                ...
# 2405        nova.osapi_compute.wsgi.server [req-96c3ec98-21a0-4af2-84a8-d4989512413e 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1916 time: 0.2677610
# 2406                                                                                                                                                                                                                              User 3844 account experienced multiple failed logins
# 2407                                                                                                   nova.metadata.wsgi.server [req-b6d4a270-accb-4c3a-8179-9611e52e1768 - - - - -] 10.11.21.124,10.11.10.1 "GET /openstack/2013-10-17 HTTP/1.1" RCODE  200 len: 157 time: 0.2249990
# 2408                                                                                                                                                                                                                                     Email service affected by failed transmission
# 2409                                                                                                                                                                                                                          Repeated failed login attempts occurred for user ID 8555
#
#         target_label complexity  cluster_label regex_classify
# 0        HTTP Status       bert              0           None
# 1     Critical Error       bert              1           None
# 2     Security Alert       bert              2           None
# 3        HTTP Status       bert              0           None
# 4        HTTP Status       bert              0           None
# ...              ...        ...            ...            ...
# 2405     HTTP Status       bert              0           None
# 2406  Security Alert       bert              7           None
# 2407     HTTP Status       bert              0           None
# 2408  Critical Error       bert              1           None
# 2409  Security Alert       bert              7           None
#
# [1968 rows x 7 columns]

# %%
# classify the llm

llm_targets = df["target_label"].value_counts()[df["target_label"].value_counts() <= 5].index.tolist()
df["source"][df.target_label.isin(llm_targets)].unique()
# Out:
# array(['LegacyCRM'], dtype=object)

# %%
#In this Nan now filter out llm and bert df

df_non_legacy = df_non_regex[df_non_regex["source"] != "LegacyCRM"]
df_non_legacy.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI'], dtype=object)

# %%
filtered_embeddings = model.encode(df_non_legacy["log_message"].tolist())
filtered_embeddings[:2]
# Out:
# array([[-1.02939621e-01,  3.35459411e-02, -2.20260732e-02,
#          1.55101740e-03, -9.86917876e-03, -1.78956270e-01,
#         -6.34409785e-02, -6.01761639e-02,  2.81109158e-02,
#          5.99620491e-02, -1.72618348e-02,  1.43363548e-03,
#         -1.49560034e-01,  3.15287686e-03, -5.66030927e-02,
#          2.71685235e-02, -1.49891041e-02, -3.54037657e-02,
#         -3.62936445e-02, -1.45410765e-02, -5.61491773e-03,
#          8.75539035e-02,  4.55120578e-02,  2.50963885e-02,
#          1.00187510e-02,  1.24267349e-02, -1.39923573e-01,
#          7.68696293e-02,  3.14095505e-02, -4.15247958e-03,
#          4.36902344e-02,  1.71250012e-02, -8.00951198e-02,
#          5.74006326e-02,  1.89091656e-02,  8.55262503e-02,
#          3.96398641e-02, -1.34371817e-01, -1.44360063e-03,
#          3.06704035e-03,  1.76854044e-01,  4.44885530e-03,
#         -1.69274509e-02,  2.24266481e-02, -4.35049310e-02,
#          6.09034160e-03, -9.98169929e-03, -6.23972900e-02,
#          1.07372422e-02, -6.04895083e-03, -7.14660808e-02,
#         -8.45799781e-03, -3.18019874e-02, -1.00518376e-01,
#          2.25873096e-04, -1.89341009e-02, -3.17793973e-02,
#          4.00860943e-02,  2.19178163e-02, -2.59528961e-02,
#          5.84525056e-02, -8.12509581e-02,  2.12029163e-02,
#         -5.02687655e-02,  1.32057499e-02,  1.32675481e-03,
#          2.27062907e-02, -3.45793478e-02,  3.91546972e-02,
#         -2.09433399e-02,  3.24829482e-03,  4.43961099e-02,
#         -9.85357612e-02, -2.88895369e-02, -6.85023936e-03,
#          5.38818911e-02,  6.46110177e-02, -2.45060585e-02,
#          3.94655429e-02,  9.02655255e-03,  1.93095822e-02,
#          6.60717934e-02,  1.02695180e-02, -4.43853624e-02,
#         -1.56523529e-02, -1.55714555e-02,  1.32904705e-02,
#         -1.16108228e-02,  4.21832167e-02, -5.44776618e-02,
#          1.29237235e-01, -2.25756839e-02,  5.26204146e-02,
#         -1.58436596e-02,  9.33165029e-02,  6.38026977e-03,
#         -9.36163496e-03, -6.08875938e-02, -3.27308029e-02,
#         -3.44816521e-02,  3.29973884e-02, -4.79392149e-02,
#         -9.81300846e-02,  2.91164629e-02, -2.70903222e-02,
#          1.81867033e-02, -1.73860490e-02, -4.40371633e-02,
#         -7.97002092e-02,  3.01647466e-02, -6.35260865e-02,
#          1.25963241e-02,  8.50249976e-02, -4.58910428e-02,
#          5.81017323e-02, -2.71001942e-02,  8.42775702e-02,
#         -4.09972817e-02, -3.37656029e-02,  1.02088144e-02,
#         -2.54193172e-02, -1.40610306e-08,  4.94446829e-02,
#         -9.04356614e-02, -6.06710389e-02,  8.29529613e-02,
#         -3.29032615e-02,  4.14910279e-02,  9.99592058e-03,
#          6.96136709e-03,  3.99230840e-03, -3.24333347e-02,
#         -3.14657018e-02, -5.33161797e-02, -3.80913652e-02,
#          1.62076838e-02,  2.45778169e-02, -7.26419911e-02,
#         -6.56893700e-02, -8.23131725e-02, -8.00500736e-02,
#         -5.36649376e-02,  5.60894758e-02, -1.10913441e-02,
#          9.62202670e-04, -1.22690313e-01, -5.13836294e-02,
#          9.96701699e-03,  1.00696459e-02,  1.07073106e-01,
#          1.19758304e-02,  1.00423656e-02, -6.28261864e-02,
#         -7.49697238e-02, -6.34075282e-03, -2.72201486e-02,
#         -1.28096193e-01, -2.62459833e-02, -1.81464087e-02,
#         -9.85360146e-02, -3.02990507e-02, -4.02614996e-02,
#          9.94291157e-02,  5.35999909e-02,  2.74899807e-02,
#         -5.53684495e-03,  8.43571126e-02,  8.35161954e-02,
#          3.74305360e-02,  7.11937249e-02,  2.98903082e-02,
#          2.32728776e-02, -3.62111889e-02,  6.20539710e-02,
#          2.15148460e-02,  5.19732535e-02,  1.45337814e-02,
#         -4.60966341e-02,  5.02554439e-02, -7.27027431e-02,
#          2.92779319e-02,  5.62663078e-02, -3.86354811e-02,
#          1.53831942e-02, -6.23094663e-02, -2.77466550e-02]], dtype=float32)

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
y = df_non_legacy["target_label"]

X_train, X_test, y_train, y_test = train_test_split(filtered_embeddings, y, test_size=0.2, random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

clf_rpt = classification_report(y_test, y_pred)
print(clf_rpt)
# Out:
#                      precision    recall  f1-score   support
#
#      Critical Error       0.93      1.00      0.96        25
#               Error       0.95      0.91      0.93        23
#         HTTP Status       1.00      1.00      1.00       217
#      Resource Usage       1.00      1.00      1.00        33
#      Security Alert       1.00      0.99      0.99        84
# System Notification       1.00      1.00      1.00        11
#
#            accuracy                           0.99       393
#           macro avg       0.98      0.98      0.98       393
#        weighted avg       0.99      0.99      0.99       393

# %%
# save the model
import joblib
import os

save_path = os.path.abspath("D:\\Tutorials ll\\python\\PythonProject\\classificationLogs\\models\\clf_model.joblib")

with open(save_path, "wb") as f:
    joblib.dump(clf, f)
